# %%
pip install semantic-kernel
# Out:
# Requirement already satisfied: semantic-kernel in d:\anaconda3\lib\site-packages (1.28.1)
# Requirement already satisfied: aiohttp~=3.8 in d:\anaconda3\lib\site-packages (from semantic-kernel) (3.9.5)
# Requirement already satisfied: cloudevents~=1.0 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.11.0)
# Requirement already satisfied: pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0 in d:\anaconda3\lib\site-packages (from semantic-kernel) (2.11.3)
# Requirement already satisfied: pydantic-settings~=2.0 in d:\anaconda3\lib\site-packages (from semantic-kernel) (2.9.1)
# Requirement already satisfied: defusedxml~=0.7 in d:\anaconda3\lib\site-packages (from semantic-kernel) (0.7.1)
# Requirement already satisfied: azure-identity>=1.13 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.21.0)
# Requirement already satisfied: numpy>=1.26.0 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.26.4)
# Requirement already satisfied: openai>=1.67 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.75.0)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in d:\anaconda3\lib\site-packages (from semantic-kernel) (0.19.5)
# Requirement already satisfied: websockets<16,>=13 in d:\anaconda3\lib\site-packages (from semantic-kernel) (15.0.1)
# Requirement already satisfied: aiortc>=1.9.0 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.11.0)
# Requirement already satisfied: opentelemetry-api~=1.24 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.32.1)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.32.1)
# Requirement already satisfied: prance~=23.6.21.0 in d:\anaconda3\lib\site-packages (from semantic-kernel) (23.6.21.0)
# Requirement already satisfied: pybars4~=0.9 in d:\anaconda3\lib\site-packages (from semantic-kernel) (0.9.13)
# Requirement already satisfied: jinja2~=3.1 in d:\anaconda3\lib\site-packages (from semantic-kernel) (3.1.4)
# Requirement already satisfied: nest-asyncio~=1.6 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.6.0)
# Requirement already satisfied: scipy>=1.15.1 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.15.2)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\anaconda3\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda3\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\anaconda3\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda3\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\anaconda3\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (1.9.3)
# Requirement already satisfied: aioice<1.0.0,>=0.9.0 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (0.10.1)
# Requirement already satisfied: av<15.0.0,>=14.0.0 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (14.3.0)
# Requirement already satisfied: cffi>=1.0.0 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (1.16.0)
# Requirement already satisfied: cryptography>=44.0.0 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (44.0.2)
# Requirement already satisfied: google-crc32c>=1.1 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (1.7.1)
# Requirement already satisfied: pyee>=13.0.0 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (13.0.0)
# Requirement already satisfied: pylibsrtp>=0.10.0 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (0.12.0)
# Requirement already satisfied: pyopenssl>=25.0.0 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (25.0.0)
# Requirement already satisfied: azure-core>=1.31.0 in d:\anaconda3\lib\site-packages (from azure-identity>=1.13->semantic-kernel) (1.33.0)
# Requirement already satisfied: msal>=1.30.0 in d:\anaconda3\lib\site-packages (from azure-identity>=1.13->semantic-kernel) (1.32.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in d:\anaconda3\lib\site-packages (from azure-identity>=1.13->semantic-kernel) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\anaconda3\lib\site-packages (from azure-identity>=1.13->semantic-kernel) (4.12.2)
# Requirement already satisfied: deprecation<3.0,>=2.0 in d:\anaconda3\lib\site-packages (from cloudevents~=1.0->semantic-kernel) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\lib\site-packages (from jinja2~=3.1->semantic-kernel) (2.1.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\anaconda3\lib\site-packages (from openai>=1.67->semantic-kernel) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\anaconda3\lib\site-packages (from openai>=1.67->semantic-kernel) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda3\lib\site-packages (from openai>=1.67->semantic-kernel) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\anaconda3\lib\site-packages (from openai>=1.67->semantic-kernel) (0.9.0)
# Requirement already satisfied: sniffio in d:\anaconda3\lib\site-packages (from openai>=1.67->semantic-kernel) (1.3.0)
# Requirement already satisfied: tqdm>4 in d:\anaconda3\lib\site-packages (from openai>=1.67->semantic-kernel) (4.66.4)
# Requirement already satisfied: isodate in d:\anaconda3\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.7.2)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in d:\anaconda3\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (4.19.2)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in d:\anaconda3\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.3.4)
# Requirement already satisfied: more-itertools in d:\anaconda3\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (10.1.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in d:\anaconda3\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in d:\anaconda3\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.7.1)
# Requirement already satisfied: parse in d:\anaconda3\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (1.20.2)
# Requirement already satisfied: werkzeug<3.1.2 in d:\anaconda3\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (3.0.3)
# Requirement already satisfied: deprecated>=1.2.6 in d:\anaconda3\lib\site-packages (from opentelemetry-api~=1.24->semantic-kernel) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in d:\anaconda3\lib\site-packages (from opentelemetry-api~=1.24->semantic-kernel) (7.0.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b1 in d:\anaconda3\lib\site-packages (from opentelemetry-sdk~=1.24->semantic-kernel) (0.53b1)
# Requirement already satisfied: chardet>=3.0 in d:\anaconda3\lib\site-packages (from prance~=23.6.21.0->semantic-kernel) (4.0.0)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in d:\anaconda3\lib\site-packages (from prance~=23.6.21.0->semantic-kernel) (0.17.21)
# Requirement already satisfied: requests>=2.25 in d:\anaconda3\lib\site-packages (from prance~=23.6.21.0->semantic-kernel) (2.32.2)
# Requirement already satisfied: six~=1.15 in d:\anaconda3\lib\site-packages (from prance~=23.6.21.0->semantic-kernel) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in d:\anaconda3\lib\site-packages (from prance~=23.6.21.0->semantic-kernel) (23.2)
# Requirement already satisfied: PyMeta3>=0.5.1 in d:\anaconda3\lib\site-packages (from pybars4~=0.9->semantic-kernel) (0.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda3\lib\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.1 in d:\anaconda3\lib\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\anaconda3\lib\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\anaconda3\lib\site-packages (from pydantic-settings~=2.0->semantic-kernel) (0.21.0)
# Requirement already satisfied: dnspython>=2.0.0 in d:\anaconda3\lib\site-packages (from aioice<1.0.0,>=0.9.0->aiortc>=1.9.0->semantic-kernel) (2.7.0)
# Requirement already satisfied: ifaddr>=0.2.0 in d:\anaconda3\lib\site-packages (from aioice<1.0.0,>=0.9.0->aiortc>=1.9.0->semantic-kernel) (0.2.0)
# Requirement already satisfied: idna>=2.8 in d:\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.67->semantic-kernel) (3.7)
# Requirement already satisfied: pycparser in d:\anaconda3\lib\site-packages (from cffi>=1.0.0->aiortc>=1.9.0->semantic-kernel) (2.21)
# Requirement already satisfied: wrapt<2,>=1.10 in d:\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api~=1.24->semantic-kernel) (1.14.1)
# Requirement already satisfied: certifi in d:\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.67->semantic-kernel) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in d:\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.67->semantic-kernel) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.67->semantic-kernel) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel) (3.17.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.10.6)
# Requirement already satisfied: PyYAML>=5.1 in d:\anaconda3\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (6.0.1)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in d:\anaconda3\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (0.4.4)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in d:\anaconda3\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity>=1.13->semantic-kernel) (2.8.0)
# Requirement already satisfied: rfc3339-validator in d:\anaconda3\lib\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in d:\anaconda3\lib\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel) (1.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests>=2.25->prance~=23.6.21.0->semantic-kernel) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests>=2.25->prance~=23.6.21.0->semantic-kernel) (2.2.2)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from tqdm>4->openai>=1.67->semantic-kernel) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in d:\anaconda3\lib\site-packages (0.21.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymongo python-dotenv semantic-kernel pydantic flask_cors
# Out:
# Requirement already satisfied: pymongo in d:\anaconda3\lib\site-packages (4.12.0)
# Requirement already satisfied: python-dotenv in d:\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: semantic-kernel in d:\anaconda3\lib\site-packages (1.28.1)
# Requirement already satisfied: pydantic in d:\anaconda3\lib\site-packages (2.11.3)
# Collecting flask_cors
#   Downloading flask_cors-5.0.1-py3-none-any.whl.metadata (961 bytes)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in d:\anaconda3\lib\site-packages (from pymongo) (2.7.0)
# Requirement already satisfied: aiohttp~=3.8 in d:\anaconda3\lib\site-packages (from semantic-kernel) (3.9.5)
# Requirement already satisfied: cloudevents~=1.0 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.11.0)
# Requirement already satisfied: pydantic-settings~=2.0 in d:\anaconda3\lib\site-packages (from semantic-kernel) (2.9.1)
# Requirement already satisfied: defusedxml~=0.7 in d:\anaconda3\lib\site-packages (from semantic-kernel) (0.7.1)
# Requirement already satisfied: azure-identity>=1.13 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.21.0)
# Requirement already satisfied: numpy>=1.26.0 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.26.4)
# Requirement already satisfied: openai>=1.67 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.75.0)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in d:\anaconda3\lib\site-packages (from semantic-kernel) (0.19.5)
# Requirement already satisfied: websockets<16,>=13 in d:\anaconda3\lib\site-packages (from semantic-kernel) (15.0.1)
# Requirement already satisfied: aiortc>=1.9.0 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.11.0)
# Requirement already satisfied: opentelemetry-api~=1.24 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.32.1)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.32.1)
# Requirement already satisfied: prance~=23.6.21.0 in d:\anaconda3\lib\site-packages (from semantic-kernel) (23.6.21.0)
# Requirement already satisfied: pybars4~=0.9 in d:\anaconda3\lib\site-packages (from semantic-kernel) (0.9.13)
# Requirement already satisfied: jinja2~=3.1 in d:\anaconda3\lib\site-packages (from semantic-kernel) (3.1.4)
# Requirement already satisfied: nest-asyncio~=1.6 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.6.0)
# Requirement already satisfied: scipy>=1.15.1 in d:\anaconda3\lib\site-packages (from semantic-kernel) (1.15.2)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda3\lib\site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.1 in d:\anaconda3\lib\site-packages (from pydantic) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in d:\anaconda3\lib\site-packages (from pydantic) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\anaconda3\lib\site-packages (from pydantic) (0.4.0)
# Requirement already satisfied: flask>=0.9 in d:\anaconda3\lib\site-packages (from flask_cors) (3.0.3)
# Requirement already satisfied: Werkzeug>=0.7 in d:\anaconda3\lib\site-packages (from flask_cors) (3.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\anaconda3\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda3\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\anaconda3\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda3\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\anaconda3\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (1.9.3)
# Requirement already satisfied: aioice<1.0.0,>=0.9.0 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (0.10.1)
# Requirement already satisfied: av<15.0.0,>=14.0.0 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (14.3.0)
# Requirement already satisfied: cffi>=1.0.0 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (1.16.0)
# Requirement already satisfied: cryptography>=44.0.0 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (44.0.2)
# Requirement already satisfied: google-crc32c>=1.1 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (1.7.1)
# Requirement already satisfied: pyee>=13.0.0 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (13.0.0)
# Requirement already satisfied: pylibsrtp>=0.10.0 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (0.12.0)
# Requirement already satisfied: pyopenssl>=25.0.0 in d:\anaconda3\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (25.0.0)
# Requirement already satisfied: azure-core>=1.31.0 in d:\anaconda3\lib\site-packages (from azure-identity>=1.13->semantic-kernel) (1.33.0)
# Requirement already satisfied: msal>=1.30.0 in d:\anaconda3\lib\site-packages (from azure-identity>=1.13->semantic-kernel) (1.32.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in d:\anaconda3\lib\site-packages (from azure-identity>=1.13->semantic-kernel) (1.3.1)
# Requirement already satisfied: deprecation<3.0,>=2.0 in d:\anaconda3\lib\site-packages (from cloudevents~=1.0->semantic-kernel) (2.1.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in d:\anaconda3\lib\site-packages (from flask>=0.9->flask_cors) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in d:\anaconda3\lib\site-packages (from flask>=0.9->flask_cors) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in d:\anaconda3\lib\site-packages (from flask>=0.9->flask_cors) (1.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\lib\site-packages (from jinja2~=3.1->semantic-kernel) (2.1.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\anaconda3\lib\site-packages (from openai>=1.67->semantic-kernel) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\anaconda3\lib\site-packages (from openai>=1.67->semantic-kernel) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda3\lib\site-packages (from openai>=1.67->semantic-kernel) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\anaconda3\lib\site-packages (from openai>=1.67->semantic-kernel) (0.9.0)
# Requirement already satisfied: sniffio in d:\anaconda3\lib\site-packages (from openai>=1.67->semantic-kernel) (1.3.0)
# Requirement already satisfied: tqdm>4 in d:\anaconda3\lib\site-packages (from openai>=1.67->semantic-kernel) (4.66.4)
# Requirement already satisfied: isodate in d:\anaconda3\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.7.2)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in d:\anaconda3\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (4.19.2)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in d:\anaconda3\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.3.4)
# Requirement already satisfied: more-itertools in d:\anaconda3\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (10.1.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in d:\anaconda3\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in d:\anaconda3\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.7.1)
# Requirement already satisfied: parse in d:\anaconda3\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (1.20.2)
# Requirement already satisfied: deprecated>=1.2.6 in d:\anaconda3\lib\site-packages (from opentelemetry-api~=1.24->semantic-kernel) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in d:\anaconda3\lib\site-packages (from opentelemetry-api~=1.24->semantic-kernel) (7.0.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b1 in d:\anaconda3\lib\site-packages (from opentelemetry-sdk~=1.24->semantic-kernel) (0.53b1)
# Requirement already satisfied: chardet>=3.0 in d:\anaconda3\lib\site-packages (from prance~=23.6.21.0->semantic-kernel) (4.0.0)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in d:\anaconda3\lib\site-packages (from prance~=23.6.21.0->semantic-kernel) (0.17.21)
# Requirement already satisfied: requests>=2.25 in d:\anaconda3\lib\site-packages (from prance~=23.6.21.0->semantic-kernel) (2.32.2)
# Requirement already satisfied: six~=1.15 in d:\anaconda3\lib\site-packages (from prance~=23.6.21.0->semantic-kernel) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in d:\anaconda3\lib\site-packages (from prance~=23.6.21.0->semantic-kernel) (23.2)
# Requirement already satisfied: PyMeta3>=0.5.1 in d:\anaconda3\lib\site-packages (from pybars4~=0.9->semantic-kernel) (0.5.1)
# Requirement already satisfied: ifaddr>=0.2.0 in d:\anaconda3\lib\site-packages (from aioice<1.0.0,>=0.9.0->aiortc>=1.9.0->semantic-kernel) (0.2.0)
# Requirement already satisfied: idna>=2.8 in d:\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.67->semantic-kernel) (3.7)
# Requirement already satisfied: pycparser in d:\anaconda3\lib\site-packages (from cffi>=1.0.0->aiortc>=1.9.0->semantic-kernel) (2.21)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from click>=8.1.3->flask>=0.9->flask_cors) (0.4.6)
# Requirement already satisfied: wrapt<2,>=1.10 in d:\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api~=1.24->semantic-kernel) (1.14.1)
# Requirement already satisfied: certifi in d:\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.67->semantic-kernel) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in d:\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.67->semantic-kernel) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.67->semantic-kernel) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel) (3.17.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.10.6)
# Requirement already satisfied: PyYAML>=5.1 in d:\anaconda3\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (6.0.1)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in d:\anaconda3\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (0.4.4)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in d:\anaconda3\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity>=1.13->semantic-kernel) (2.8.0)
# Requirement already satisfied: rfc3339-validator in d:\anaconda3\lib\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in d:\anaconda3\lib\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel) (1.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests>=2.25->prance~=23.6.21.0->semantic-kernel) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests>=2.25->prance~=23.6.21.0->semantic-kernel) (2.2.2)
# Downloading flask_cors-5.0.1-py3-none-any.whl (11 kB)
# Installing collected packages: flask_cors
# Successfully installed flask_cors-5.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nest_asyncio
# Out:
# Requirement already satisfied: nest_asyncio in d:\anaconda3\lib\site-packages (1.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load the API key from a file
with open("OpenAI_API.txt", "r") as file:
    openai_api_key = file.read().strip()

# Use it (example for OpenAI library)
import openai
openai.api_key = openai_api_key

# %%
import os
from dotenv import load_dotenv
load_dotenv()  # Load the .env file
model_id_agent1 = os.getenv("OPENAI_CHAT_MODEL3")
model_id_agent2 = os.getenv("OPENAI_CHAT_MODEL4")
api_key = os.getenv("OPENAI_API_KEY")

# %%
import asyncio
from semantic_kernel.agents import ChatCompletionAgent
from semantic_kernel.connectors.ai.open_ai import  OpenAIChatCompletion,OpenAIChatPromptExecutionSettings
from semantic_kernel.functions.kernel_function_decorator import kernel_function
from semantic_kernel.functions import kernel_function,KernelArguments
from typing import Annotated
from pydantic import BaseModel
import pandas as pd

transactions = pd.DataFrame({
    "merchant": ["Starbucks", "Chipotle", "Walmart", "Starbucks", "Domino's"],
    "category": ["Food", "Food", "Groceries", "Food", "Food"],
    "amount": [5.50, 12.75, 80.00, 6.25, 18.00],
    "date": ["2024-03-10", "2024-03-12", "2024-03-15", "2024-03-18", "2024-03-21"]
})

# @kernel_function
# def classify_task(self, user_input: str) -> str:
#     """
#     Return either 'analysis' or 'data_retrieval' based on user intent.
#     """
    
# 🧩 Plugin class with logging
class ExpensePlugin:
    @kernel_function(description="Get total monthly food spending.")
    def get_monthly_food_expense(self) -> Annotated[str, "Returns the total spent on food last month."]:
        print("[LOG] Plugin function 'get_monthly_food_expense' was called by Analyst_Agent.")
        return "[ExpensePlugin used] Based on your data, you spent $452 on food last month."

class DatabasePlugin:

    @kernel_function(description="Get all restaurant names the user spent money on.")
    def get_restaurants(self) -> Annotated[str, "Returns a list of unique food merchants."]:
        print("[LOG] get_restaurants called.")
        food_merchants = transactions[transactions["category"] == "Food"]["merchant"].unique()
        return ", ".join(food_merchants)

    @kernel_function(description="Get total spending at a specific merchant.")
    def get_spending_by_merchant(self, merchant: Annotated[str, "The name of the merchant."]) -> Annotated[str, "Returns total spent."]:
        print(f"[LOG] get_spending_by_merchant called for: {merchant}")
        total = transactions[transactions["merchant"].str.lower() == merchant.lower()]["amount"].sum()
        return f"You spent ${total:.2f} at {merchant}."

# Structured response (optional)
class ExpenseSummary(BaseModel):
    category: str
    amount: float

thread = None
settings = OpenAIChatPromptExecutionSettings()
#settings.response_format = ExpenseSummary  # Structured output
#args = KernelArguments(settings)

#this is the analyst agent that will use tools as plugin and handle all the issues like cost summary tables, give recommendations on savings, and analyse the data as Customer sercvice agent requested
Analyst_Agent = ChatCompletionAgent(
        service=OpenAIChatCompletion(ai_model_id=model_id_agent2, api_key=api_key),
        name="Analyst_Agent",
        instructions= "You are an invisible backend analyst.. Evaluate user requests using appropriate tools. "\
            "Always begin with: '[Analyst_Agent activated]'. "\
            "If you can use plugins to get the data you need and complete the task."\
            "You are not allowed to use any other plugins or tools which not in the plugins that provided to you. "
            "If the request is not solvable with plugins, reply with: '[Forwarding back to Customer_Service_Agent]'."
            "Otherwise, provide the completed analysis directly as part of your response.",
        plugins=[ExpensePlugin()], # 所有function放在这里
        arguments=KernelArguments(settings)
    )

Database_Agent = ChatCompletionAgent(
    service=OpenAIChatCompletion(ai_model_id=model_id_agent2, api_key=api_key),
    name="Database_Agent",
    instructions=(
        "You are a backend data retrieval agent. "
        "You do NOT interact with the user directly. "
        "Only the Customer_Service_Agent can talk to the user. "
        "If a request lacks information (e.g., merchant name, date, category), ask the Customer_Service_Agent to gather the missing info. "
        "Be concise, and return data or ask only for clarification needed to complete the task."
    ),
    plugins=[DatabasePlugin()]
)

# This is the main agent that commnunicate with user
Customer_Service_Agent = ChatCompletionAgent(
    service=OpenAIChatCompletion(ai_model_id=model_id_agent1, api_key=api_key),
    name="Customer_Service_Agent",
    instructions=(
        "You are the only agent who talks to the user. "
        "You use internal agents to fulfill requests: \n"
        "- Use **Analyst_Agent** for any task that involves analysis, summaries, trends, total spending calculations, charts, or recommendations. \n"
        "- Use **Database_Agent** only for direct fact-based retrieval, such as 'what restaurants did I go to', 'when did I visit Starbucks', or 'how many times did I shop at Walmart'.\n\n"
        "If a request lacks information (like merchant or date), ask Database_Agent to clarify — then ask the user. "
        "Always integrate responses and present them in your own voice. Do not reveal internal agents."
    ),
    plugins=[Analyst_Agent, Database_Agent]
)

# Customer_Service_Agent = ChatCompletionAgent(
#         service=OpenAIChatCompletion(ai_model_id=model_id_agent1, api_key=api_key),
#         name="Customer_Service_Agent",
#         instructions="You are a customer service assistant. Handle general inquiries. "\
#         "If the user asks for specific calculations like food spending, forward the request to Analyst_Agent and wait for a result. "\
#         "Prefix this with '[Forwarding to Analyst_Agent]'. After receiving the result, prefix it with '[Response from Analyst_Agent]' "\
#         "and respond fully. After every response, ask the user if they have another question." ,
#         plugins=[Analyst_Agent, Database_Agent],  # Add the Analyst_Agent as a plugin
#     )

thread: None


async def main():
    print("[LOG] User sends message to Customer_Service_Agent...")
    #user_message = "Which restaurants did I spend on this month?"
    user_message = "Can you help me to analyze how much I spent in total last month?"

    print("[LOG] User asked:", user_message)

    response = await Customer_Service_Agent.get_response(messages=user_message)
    print("[LOG] Final response from Customer_Service_Agent:")
    print(response.content)

await main()
# Output:
# Language's essence,
# Semantic threads intertwine,
# Meaning's core revealed.
# Out:
# [LOG] User sends message to Customer_Service_Agent...
# [LOG] User asked: Can you help me to analyze how much I spent in total last month?
# [LOG] Plugin function 'get_monthly_food_expense' was called by Analyst_Agent.
# [LOG] Final response from Customer_Service_Agent:
# You spent a total of $452 on food last month. If you need more specific details or analysis, feel free to ask!
